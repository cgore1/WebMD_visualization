# %%
import gensim, logging
import re
import csv, sys
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize
from __future__ import division, unicode_literals
import math
from textblob import TextBlob as tb
import shutil
import operator
import json
import gensim, logging
import pandas as pd
from textblob import Word
from textblob.wordnet import VERB
from textblob.taggers import NLTKTagger
import os
from nltk.corpus import wordnet

from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import datetime

# %%
#Load all the joined data and setup environment
allData = pd.read_csv("webmd-all-join.csv")
stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", '?', '-','!', ':', ';', '(', ')', '[', ']', '{', '}']) # remove it if you need punctuation 
tokenizer = RegexpTokenizer(r'\w+')
nltk_tagger = NLTKTagger()

# %%
wordLimit = 5
word2VecLimit = 5
modelMinCount = 23
modelDimensions = 300
modelName = "MODEL_" + str(modelMinCount) + "_" + str(modelDimensions)
path = "C:\\Users\\Aarav\\"
verbose = True

# %%
#Tf-IDF calculation fucntions
def tf(word, blob):
    return blob.words.count(word) / len(blob.words)

def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob.words)

def idf(word, bloblist):
    return math.log(len(bloblist) / (1 + n_containing(word, bloblist)))

def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)

# %%
#Convert treebank tag to WordNet tag
def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
#Return POS tags of the sentence words
def POStags(sentence):
    blob = tb(sentence, pos_tagger=nltk_tagger)
    return blob.pos_tags

# %%
# Return a sentence with each word converted to its root form
def lemmatize(sentence):
    sen = []
    for token in POStags(sentence):
        word = Word(token[0])
        try:
            word = word.lemmatize(get_wordnet_pos(token[1]))
        except:
            pass
        sen.append(word)
    return sen

# %%
def nameAndMeaning(word):
    print Word(word).definitions, "\n"
    print model.most_similar(positive = [word])

# %%
#Get K most similar words for a input word using word2vec model trained on the answer data
def modelWords(word, topk):
    words =  model.most_similar(positive = [word], topn=topk)
    wordKeys = []
    for i in range(len(words)):
        wordKeys.append(words[i][0])
    return wordKeys

# %%
#Return WordNet meaning of words
def getWordNetMeanings(key):
    return Word(key).definitions

# %%
#Return a sorted list  
def getTopics():
    df = allData[['topicname', 'answercontent']]
    topics = df.topicname.unique()
    topics.sort()
    return topics

# %%
#Check if a quantity is NaN
def isNaN(num):
    return num != num

# %%
def trainModel(modelName, minCount, dimensions):
    sentences = []
    f = open(path+"dataAnswers.txt")
    reader = csv.reader(f)  
    for row in reader:  
        data = ""
        for item in row:
            data = data + item
        #print data
        raw = data.lower()
        tokens = tokenizer.tokenize(raw)
        en_stop = get_stop_words('en')
        stopped_tokens = [i for i in tokens if not i in en_stop]
        
        raw = " ".join(stopped_tokens)
        raw = lemmatize(raw)
        #raw = " ".join(raw)
        sentences.append(raw)
        
    model = gensim.models.Word2Vec(sentences, min_count=minCount, size=dimensions)
    model.save(modelName)

# %%
#tf-idf over all topics 
def globalTfIdf(verbose, wordLimit):
    bloblist = []
    topics = getTopics()
    df = allData[['topicname', 'answercontent']]
    
    for topic in topics:
        if  isNaN(topic) is False:
            d = df.loc[df['topicname'] == topic]
            nonEmpty = d['answercontent'] != ' '
            d = d[nonEmpty]
            corpus =  d['answercontent'].tolist()

            total = ""
            raw = ""
            
            for sentence in corpus:
                
                raw = sentence.lower()
                tokens = lemmatize(raw)
                en_stop = get_stop_words('en')
                stopped_tokens = [i for i in tokens if not i in en_stop]
                raw = " ".join(stopped_tokens)
                total = total + raw
                
            bloblist.append(tb(total))

    globalDict = []
    for i, blob in enumerate(bloblist):
        #print("Top words in document {}".format(i + 1))
        if verbose:
            print "Top words in document ", topics[i]
        scores = {word: tfidf(word, blob, bloblist) for word in blob.words}
        sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        wordsData = {}
        dict = {}
        for word, score in sorted_words[:wordLimit]:
            #print("\tWord: {}, TF-IDF: {}".format(word, round(score, 5)))
            wordsData[word] = round(score,5)
        dict["topic"] = topics[i]
        dict["words"] = wordsData

        globalDict.append(dict)

    try:
        os.remove('tf_idf.json')
    except OSError:
        pass
    with open('tf_idf.json', 'w') as outfile:
        json.dump(globalDict, outfile)

# %%
def word2VecTopK(topK):
    with open('tf_idf.json') as infile:
        array = json.load(infile)

    dict = []
    for i in range(len(array)):

        data = {}
        wordlist = []
        wordNetMeaningList = []
        wordNetMeaningDict = {}
        for key, value in array[i]['words'].iteritems():
            word2vecWords = []
            try:
                wordNetMeaningDict[key] = getWordNetMeanings(key)
                word2vecWords = modelWords(key, topK)
            except:
                pass

            for word in word2vecWords:
                if(word not in wordlist):
                    wordlist.append(word)

        wordNetMeaningList.append(wordNetMeaningDict)       
        data['topic'] = array[i]['topic']
        data['word2VecList'] = wordlist
        data['wordNetMeanings'] = wordNetMeaningList
        dict.append(data)

    try:
        os.remove('word2vecAndTfidf.json')
    except OSError:
        pass
    with open('word2vecAndTfidf.json', 'w') as outfile:
        json.dump(dict, outfile)

# %%
#Topics for each member to create member graph edges by interesection 
def generateMemberList():
    globalList = []
    information = allData[['questiontopicid','membername']]
    members = allData['membername'].unique().tolist()
    for member in members:
        if isNaN(member) is False:
            data = {}
            d = information.loc[information['membername'] == member]
            topicListForUser = []
            for question in d['questiontopicid'].unique().tolist():
                if isNaN(question) is False:
                    categories = question.split(',')
                    for category in categories:
                        topic =  category.split('-questions')[0].strip()
                        if topic not in topicListForUser:
                            topicListForUser.append(topic)
            member =  member.split(",")[0]
            data['member'] = member
            data['topics'] = topicListForUser
            if topicListForUser is []:
                print member
            globalList.append(data)
    try:
        os.remove('topicListForUser.json')
    except OSError:
        pass
    with open('topicListForUser.json', 'w') as outfile:
        json.dump(globalList, outfile)

# %%
#get helpfulvotes of members in each topic
def generateTopicMemberList():
    globalDict = {}
    df = allData[['topicname', 'membername','memberhelpfulvotes']]
    
    topics = getTopics()
    
    for topic in topics:
        if isNaN(topic) is False:
            data = {}
            d = df.loc[df['topicname'] == topic]
            members = d['membername'].unique().tolist() 
            memberList = []
            memberVotes = []
            for member in members:
                if isNaN(member) is False:
                    if member not in memberList:
                        d = df.loc[df['membername'] == member]
                        memberVotes.append(d['memberhelpfulvotes'].unique().tolist()[0])
                        member =  member.split(",")[0]
                        memberList.append(member)
            data['members'] = memberList
            data['memberhelpfulvotes'] = memberVotes
            globalDict[topic] = data
    
        try:
            os.remove('TopicMemberList.json')
        except OSError:
            pass
        with open('TopicMemberList.json', 'w') as outfile:
            json.dump(globalDict, outfile)

# %%
#Get location information for each  user
def generateMemberLocation():
    memLocation = pd.read_csv("member_location.csv")
    members = memLocation.membername.unique().tolist()
    globalData = []
    for member in members:
        if isNaN(member) is False:
            data = {}
            d = memLocation.loc[memLocation['membername']==member]
            data['member'] = member.split(",")[0]
            data['location'] = d.location.unique().tolist()[0]
            globalData.append(data)

        try:
            os.remove('memberLocation.json')
        except OSError:
            pass
        with open('memberLocation.json', 'w') as outfile:
            json.dump(globalData, outfile)

# %%
#Restrict to 10 members per topics
def sortTop10TopicMemberList():
    inputdata = json.loads(open("TopicMemberList.json").read())
    globalDict = {}
    for topic, values in inputdata.iteritems():
        data = {}
        memberhelpfulvotes = []
        members = []
        sortedMembers = []
        for keyNext, value in values.iteritems():
            if keyNext == 'memberhelpfulvotes':
                memberhelpfulvotes = value
            if keyNext == 'members':
                members = value
        sortedVotes =  sorted(memberhelpfulvotes, reverse = True)
        for item in sortedVotes:
            sortedMembers.append(members[memberhelpfulvotes.index(item)])

        data['members'] = sortedMembers[ :10]
        data['memberhelpfulvotes'] = sortedVotes[:10]
        globalDict[topic] = data

    try:
        os.remove('TopicMemberListTop10.json')
    except OSError:
        pass
    with open('TopicMemberListTop10.json', 'w') as outfile:
        json.dump(globalDict, outfile)

# %%
#Get state mapping for each topic by getting counts of members state info
def getStateForTopic():
    
    inputMemberLocation = json.loads(open("memberLocation.json").read())
    inputTopics = json.loads(open("TopicMemberListTop10.json").read())
    
    globalTopicData = {}
    for topic, values in inputTopics.iteritems():
        for keyNext, value in values.iteritems():
            data = {}
            memberhelpfulvotes = []
            members = []
            if keyNext == 'memberhelpfulvotes':
                memberhelpfulvotes = value
            if keyNext == 'members':
                members = value 

            for item in inputMemberLocation:
                state = item['location']
                if item['member'] in members:
                    if state in data:
                        data[state] = data[state] +1
                    else:
                        data[state] = 1
            globalTopicData[topic] = data

    try:
        os.remove('stateForTopic.json')
    except OSError:
        pass
    with open('stateForTopic.json', 'w') as outfile:
        json.dump(globalTopicData, outfile)

# %%
#Get fraction of answers made by experts for each topic 
def getExpertAnswers():
    df = allData[['topicname', 'answercontent', 'membertype']]
    topics = df.topicname.unique()
    globalData = {}

    for topic in getTopics():
        if isNaN(topic) is False:
            data = {}
            d = df.loc[df['topicname'] == topic]
            nonEmpty = d['answercontent'] != ' '
            d = d[nonEmpty]
            data['totalAnswers'] = len(d)
            dm = d.loc[d['membertype'] == 'Expert']
            data['expertAnswers'] = len(dm)
            globalData[topic] = data
    try:
        os.remove('expertAnswers.json')
    except OSError:
        pass
    with open('expertAnswers.json', 'w') as outfile:
        json.dump(globalData, outfile)

# %%
def getDatesYear():
    nodes = []

    for topic in getTopics():
        months = {}
        globalData = {}

        if isNaN(topic) is False:
            d = allData.loc[allData['topicname'] == topic]
            nonEmpty = d['answerpostdate'] != ' '
            d = d[nonEmpty]
            corpus =  d['answerpostdate'].tolist()
            for date in corpus:
                date_object = datetime.datetime.strptime(date, '%Y-%m-%d %H:%M:%S')
                if date_object.month in months:
                    months[date_object.month] =  months[date_object.month] + 1
                else:
                     months[date_object.month] = 1 
            globalData[topic] = months
            nodes.append(globalData)
    try:
        os.remove('monthData.json')
    except OSError:
        pass
    with open('monthData.json', 'w') as outfile:
        json.dump(nodes, outfile)

# %%
def getDatesHour():
    nodes = []

    for topic in getTopics():
        hours = {}
        globalData = {}

        if isNaN(topic) is False:
            d = allData.loc[allData['topicname'] == topic]
            nonEmpty = d['answerpostdate'] != ' '
            d = d[nonEmpty]
            corpus =  d['answerpostdate'].tolist()

            for date in corpus:
                date_object = datetime.datetime.strptime(date, '%Y-%m-%d %H:%M:%S')
                if date_object.hour in hours:
                    hours[date_object.hour] =  hours[date_object.hour] + 1
                else:
                     hours[date_object.hour] = 1 
            globalData[topic] = hours
            nodes.append(globalData)
    try:
        os.remove('hourData.json')
    except OSError:
        pass
    with open('hourData.json', 'w') as outfile:
        json.dump(nodes, outfile)

# %%
#Calculate TF-IDF
globalTfIdf(verbose, wordLimit)
# Out:
# Top words in document  nan
# Top words in document  AIDS
# Top words in document  ANA Test
# Top words in document  Abdominal Obesity
# Top words in document  Abdominal Pain
# Top words in document  Ablation
# Top words in document  Acetaminophen
# Top words in document  Acne
# Top words in document  Actinic Keratosis
# Top words in document  Acupuncture
# Top words in document  Addiction
# Top words in document  Adrenal Gland
# Top words in document  Adult Acne
# Top words in document  Affordable Care Act
# Top words in document  Aging
# Top words in document  Alcohol Abuse
# Top words in document  Alcoholic Beverage
# Top words in document  Alcoholism
# Top words in document  Allergic Conjunctivitis
# Top words in document  Allergic Reaction
# Top words in document  Allergy
# Top words in document  Almond
# Top words in document  Aloe
# Top words in document  Alopecia
# Top words in document  Alzheimer's Disease
# Top words in document  Amino Acids
# Top words in document  Ammonia
# Top words in document  Amoxicillin
# Top words in document  Amyotrophic Lateral Sclerosis
# Top words in document  Anaphylaxis
# Top words in document  Anemia
# Top words in document  Anesthesia
# Top words in document  Anger
# Top words in document  Angina
# Top words in document  Ankle
# Top words in document  Anterior Cruciate Ligament Injury
# Top words in document  Anti-Aging
# Top words in document  Antibiotic
# Top words in document  Antidepressant
# Top words in document  Anus
# Top words in document  Anxiety
# Top words in document  Apnea
# Top words in document  Arm
# Top words in document  Arrhythmia
# Top words in document  Arthritis
# Top words in document  Aspirin
# Top words in document  Asthma
# Top words in document  Asthma Attack
# Top words in document  Atherosclerosis
# Top words in document  Athlete's Foot
# Top words in document  Atopic Dermatitis
# Top words in document  Attention Deficit Hyperactivity Disorder
# Top words in document  Autism
# Top words in document  Autoimmune Hepatitis
# Top words in document  B Complex Vitamins
# Top words in document  B12
# Top words in document  Baby
# Top words in document  Baby Bottle Tooth Decay
# Top words in document  Back Pain
# Top words in document  Bacterial Vaginosis
# Top words in document  Bacterium
# Top words in document  Bad Breath
# Top words in document  Balanitis
# Top words in document  Bedbug
# Top words in document  Bee Sting
# Top words in document  Belch
# Top words in document  Belly Button
# Top words in document  Benign Prostatic Hyperplasia
# Top words in document  Benzoyl Peroxide
# Top words in document  Beta Blocker
# Top words in document  Big Toe
# Top words in document  Bioidentical Hormone
# Top words in document  Biopsy
# Top words in document  Bipolar Disorder
# Top words in document  Birth
# Top words in document  Birth Control
# Top words in document  Birth Control Pill
# Top words in document  Birth Defect
# Top words in document  Birthmark
# Top words in document  Bladder
# Top words in document  Blister
# Top words in document  Bloating
# Top words in document  Blood Clot
# Top words in document  Blood Pressure
# Top words in document  Blood Sugar
# Top words in document  Blood Test
# Top words in document  Body Mass Index
# Top words in document  Boil
# Top words in document  Bone Spurs
# Top words in document  Borderline Personality Disorder
# Top words in document  Bowel Movement
# Top words in document  Brain
# Top words in document  Brain Tumor
# Top words in document  Breast
# Top words in document  Breast Cancer
# Top words in document  Breast Self Exam
# Top words in document  Breastfeed
# Top words in document  Broken Toe
# Top words in document  Bronchitis
# Top words in document  Bruise
# Top words in document  Burn
# Top words in document  Bursitis
# Top words in document  Buttocks
# Top words in document  Caffeine
# Top words in document  Calcium
# Top words in document  Calf
# Top words in document  Callus
# Top words in document  Calorie
# Top words in document  Cancer
# Top words in document  Canker Sore
# Top words in document  Carbohydrate
# Top words in document  Carbon Dioxide
# Top words in document  Cardiovascular Disease
# Top words in document  Cardioversion
# Top words in document  Carotid Artery
# Top words in document  Carpal Tunnel Syndrome
# Top words in document  Castor Oil
# Top words in document  Cat Scratch Disease
# Top words in document  Catheter
# Top words in document  Cats
# Top words in document  Cavity
# Top words in document  Celiac Disease
# Top words in document  Cellulite
# Top words in document  Cephalexin
# Top words in document  Cereal
# Top words in document  Cervical Conization
# Top words in document  Cervix
# Top words in document  Cesarean Section
# Top words in document  Charcot-Marie-Tooth Disease
# Top words in document  Chemotherapy
# Top words in document  Cherry Angioma
# Top words in document  Chest
# Top words in document  Chiari Malformation
# Top words in document  Chickenpox
# Top words in document  Chigger
# Top words in document  Childhood Obesity
# Top words in document  Chlamydia
# Top words in document  Choking
# Top words in document  Cholesterol
# Top words in document  Chondromalacia Patella
# Top words in document  Chronic Obstructive Pulmonary Disease
# Top words in document  Circumcision
# Top words in document  Cirrhosis
# Top words in document  Cocaine
# Top words in document  Cocoa
# Top words in document  Coconut Oil
# Top words in document  Coffee
# Top words in document  Cold
# Top words in document  Cold Sore
# Top words in document  Coldness
# Top words in document  Colic
# Top words in document  Colitis
# Top words in document  Collagen
# Top words in document  Colon
# Top words in document  Colon Cancer
# Top words in document  Colonoscopy
# Top words in document  Complex Regional Pain Syndrome
# Top words in document  Concussion
# Top words in document  Condom
# Top words in document  Congestive Heart Failure
# Top words in document  Constipation
# Top words in document  Contact Dermatitis
# Top words in document  Cooking
# Top words in document  Cortisone
# Top words in document  Cosmetic Procedures
# Top words in document  Cosmetic Surgery
# Top words in document  Cough
# Top words in document  Cramps
# Top words in document  Cranberry
# Top words in document  Craving
# Top words in document  Creatinine
# Top words in document  Crohn's Disease
# Top words in document  Croup
# Top words in document  Crying
# Top words in document  Cuts
# Top words in document  Cyst
# Top words in document  Cystic Acne
# Top words in document  Dairy
# Top words in document  Dark Chocolate
# Top words in document  Deep Vein Thrombosis
# Top words in document  Dehydration
# Top words in document  Dementia
# Top words in document  Dental
# Top words in document  Dental Injury
# Top words in document  Depression
# Top words in document  Dessert
# Top words in document  Detached Retina
# Top words in document  Diabetes
# Top words in document  Diabetic Neuropathy
# Top words in document  Diaper Rash
# Top words in document  Diarrhea
# Top words in document  Diet
# Top words in document  Diet Pills
# Top words in document  Digestive System
# Top words in document  Dislocation
# Top words in document  Diverticulitis
# Top words in document  Dizziness
# Top words in document  Dog
# Top words in document  Domestic Violence
# Top words in document  Dopamine
# Top words in document  Drainage
# Top words in document  Drinking
# Top words in document  Drowsiness
# Top words in document  Drug
# Top words in document  Drug Abuse
# Top words in document  Drug Overdose
# Top words in document  Drug Test
# Top words in document  Dry Mouth
# Top words in document  Dry Skin
# Top words in document  Dry Socket
# Top words in document  Ear Drum
# Top words in document  Ear Infection
# Top words in document  Ears
# Top words in document  Echocardiogram
# Top words in document  Ectopic Pregnancy
# Top words in document  Edema
# Top words in document  Ehlers-Danlos Syndrome
# Top words in document  Ejaculation
# Top words in document  Elbow
# Top words in document  Electrocardiogram
# Top words in document  Electrogastrogram
# Top words in document  Emergency Room
# Top words in document  Endometrial Cancer
# Top words in document  Endometriosis
# Top words in document  Epilepsy
# Top words in document  Epinephrine
# Top words in document  Epistaxis
# Top words in document  Erectile Dysfunction
# Top words in document  Erection
# Top words in document  Esophagus
# Top words in document  Estrogen
# Top words in document  Eustachian Tube Dysfunction
# Top words in document  Exercise
# Top words in document  Exercise Stress Test
# Top words in document  Exposure
# Top words in document  Eyebrow
# Top words in document  Eyelid
# Top words in document  Eyes
# Top words in document  Facial Nerve
# Top words in document  Family
# Top words in document  Fast Food
# Top words in document  Fatigue
# Top words in document  Fatty Liver Disease
# Top words in document  Fear
# Top words in document  Feeding
# Top words in document  Femur
# Top words in document  Fertility
# Top words in document  Fetal Alcohol Syndrome
# Top words in document  Fetus
# Top words in document  Fever
# Top words in document  Fiber
# Top words in document  Fibromyalgia
# Top words in document  Finger
# Top words in document  First Aid
# Top words in document  First Trimester
# Top words in document  Fish
# Top words in document  Fitness
# Top words in document  Flatulence
# Top words in document  Flu
# Top words in document  Fluoride
# Top words in document  Food
# Top words in document  Food Allergy
# Top words in document  Food Poisoning
# Top words in document  Foot
# Top words in document  Forearm
# Top words in document  Forehead
# Top words in document  Foreskin
# Top words in document  Fracture
# Top words in document  Freckle
# Top words in document  Fruit
# Top words in document  Fuzziness
# Top words in document  Gallbladder
# Top words in document  Gallstone
# Top words in document  Ganglion Cyst
# Top words in document  Gastric Bypass Surgery
# Top words in document  Gastroenteritis
# Top words in document  General Anesthesia
# Top words in document  Genetic Disorder
# Top words in document  Genetic Testing
# Top words in document  Genital Herpes
# Top words in document  Ginger
# Top words in document  Gingivitis
# Top words in document  Ginkgo Biloba
# Top words in document  Ginseng
# Top words in document  Glaucoma
# Top words in document  Gonorrhea
# Top words in document  Gout
# Top words in document  Grapefruit
# Top words in document  Grayness
# Top words in document  Gum Disease
# Top words in document  H. Pylori
# Top words in document  HIV
# Top words in document  HIV Test
# Top words in document  Hair
# Top words in document  Hair Loss
# Top words in document  Hallucination
# Top words in document  Hamburger
# Top words in document  Hand
# Top words in document  Head
# Top words in document  Head Lice
# Top words in document  Headache
# Top words in document  Healing
# Top words in document  Health insurance
# Top words in document  Healthy Eating
# Top words in document  Heart
# Top words in document  Heart Attack
# Top words in document  Heart Disease
# Top words in document  Heart Murmur
# Top words in document  Heart Surgery
# Top words in document  Heartburn
# Top words in document  Heel
# Top words in document  Height
# Top words in document  Hemorrhoid
# Top words in document  Hepatitis
# Top words in document  Hepatitis A
# Top words in document  Hepatitis B
# Top words in document  Hepatitis C
# Top words in document  Herb
# Top words in document  Hernia
# Top words in document  Herniated Disc
# Top words in document  Herniated Disk
# Top words in document  Herpes
# Top words in document  Herpes Simplex
# Top words in document  Hiatal Hernia
# Top words in document  High Blood Pressure
# Top words in document  High Cholesterol
# Top words in document  High Fructose Corn Syrup
# Top words in document  High-Risk Pregnancy
# Top words in document  Hip Pain
# Top words in document  Hives
# Top words in document  Hoarseness
# Top words in document  Honey
# Top words in document  Hormone
# Top words in document  Hormone Replacement Therapy
# Top words in document  Hot Flash
# Top words in document  Human Papillomavirus
# Top words in document  Hunger
# Top words in document  Hydrocodone
# Top words in document  Hydrocortisone
# Top words in document  Hydrogen Peroxide
# Top words in document  Hyperglycemia
# Top words in document  Hyperhidrosis
# Top words in document  Hyperkalemia
# Top words in document  Hyperpigmentation
# Top words in document  Hyperthyroidism
# Top words in document  Hypertrophic Cardiomyopathy
# Top words in document  Hypothermia
# Top words in document  Hypothyroidism
# Top words in document  Hysterectomy
# Top words in document  Ibuprofen
# Top words in document  Ice Cream
# Top words in document  Ichthyosis
# Top words in document  Immune System
# Top words in document  Immunotherapy
# Top words in document  Impetigo
# Top words in document  Implant Radiation
# Top words in document  Impotence
# Top words in document  Incontinence
# Top words in document  Indigestion
# Top words in document  Infant
# Top words in document  Infection
# Top words in document  Infertility
# Top words in document  Inhaler
# Top words in document  Injection
# Top words in document  Injury
# Top words in document  Insect Bite
# Top words in document  Insect Sting
# Top words in document  Insomnia
# Top words in document  Insulin
# Top words in document  Insurance
# Top words in document  Intestine
# Top words in document  Intrauterine Device
# Top words in document  Intrauterine Insemination
# Top words in document  Iodine
# Top words in document  Iron
# Top words in document  Irregularity
# Top words in document  Irritability
# Top words in document  Irritable Bowel Syndrome
# Top words in document  Itch
# Top words in document  Jaw
# Top words in document  Jelly
# Top words in document  Jet Lag
# Top words in document  Juice
# Top words in document  Kale
# Top words in document  Keloid
# Top words in document  Keratosis Pilaris
# Top words in document  Kidney
# Top words in document  Kidney Cancer
# Top words in document  Kidney Disease
# Top words in document  Kidney Failure
# Top words in document  Kidney Stone
# Top words in document  Knee
# Top words in document  Knee Pain
# Top words in document  Lactase
# Top words in document  Lactose
# Top words in document  Leg
# Top words in document  Legg-Calve-Perthes Disease
# Top words in document  Libido
# Top words in document  Lice
# Top words in document  Lice Infestation
# Top words in document  Ligament
# Top words in document  Lightheadedness
# Top words in document  Lip
# Top words in document  Liposuction
# Top words in document  Lithium
# Top words in document  Little Finger
# Top words in document  Liver
# Top words in document  Long-Term Effect
# Top words in document  Lotion
# Top words in document  Low Blood Pressure
# Top words in document  Low Carb Diet
# Top words in document  Low Self-Esteem
# Top words in document  Lubricants
# Top words in document  Lump
# Top words in document  Lung
# Top words in document  Lupus
# Top words in document  Lyme Disease
# Top words in document  Lymph Node
# Top words in document  Lymphedema
# Top words in document  Macadamia
# Top words in document  Magnesium
# Top words in document  Magnetic Resonance Imaging
# Top words in document  Makeup
# Top words in document  Mammogram
# Top words in document  Manic Depressive
# Top words in document  Marijuana
# Top words in document  Masturbation
# Top words in document  Mayonnaise
# Top words in document  Meal
# Top words in document  Measles
# Top words in document  Meat
# Top words in document  Medicaid
# Top words in document  Medicare
# Top words in document  Melanoma
# Top words in document  Melasma
# Top words in document  Melatonin
# Top words in document  Memory Loss
# Top words in document  Meningitis
# Top words in document  Menopause
# Top words in document  Menstrual
# Top words in document  Menstrual Cramp
# Top words in document  Mental Health
# Top words in document  Metabolism
# Top words in document  Methadone
# Top words in document  Middle Ear
# Top words in document  Migraine
# Top words in document  Milk
# Top words in document  Mite
# Top words in document  Mitochondrial Myopathy
# Top words in document  Molar
# Top words in document  Mold
# Top words in document  Mole
# Top words in document  Mononucleosis
# Top words in document  Mood Swing
# Top words in document  Morning After Pill
# Top words in document  Morning Sickness
# Top words in document  Morphine
# Top words in document  Motion Sickness
# Top words in document  Mouth
# Top words in document  Mouth Ulcers
# Top words in document  Movement
# Top words in document  Mucus
# Top words in document  Multiple Sclerosis
# Top words in document  Multivitamin
# Top words in document  Mumps
# Top words in document  Muscle
# Top words in document  Myasthenia Gravis
# Top words in document  NAFLD
# Top words in document  NASH
# Top words in document  Nail
# Top words in document  Nail Fungus
# Top words in document  Naproxen
# Top words in document  Narcolepsy
# Top words in document  Narcotic
# Top words in document  Nasal Spray
# Top words in document  Nausea
# Top words in document  Nebulization
# Top words in document  Neck
# Top words in document  Nerve
# Top words in document  Neuropathy
# Top words in document  Newborn
# Top words in document  Nicotine
# Top words in document  Night Terror
# Top words in document  Nightmare
# Top words in document  Nose
# Top words in document  Nostril
# Top words in document  Nsaid
# Top words in document  Numbness
# Top words in document  Nutrition
# Top words in document  Oatmeal
# Top words in document  Obesity
# Top words in document  Obstructive Sleep Apnea
# Top words in document  Oil
# Top words in document  Olive
# Top words in document  Omega-3
# Top words in document  Oral Cancer
# Top words in document  Organ
# Top words in document  Orgasm
# Top words in document  Osteoarthritis
# Top words in document  Osteoporosis
# Top words in document  Ovarian Cancer
# Top words in document  Ovary
# Top words in document  Over The Counter
# Top words in document  Overactive Bladder
# Top words in document  Ovulation
# Top words in document  Oxycodone
# Top words in document  Pacemaker
# Top words in document  Pain
# Top words in document  Pain Relief
# Top words in document  Painful Urination
# Top words in document  Pancreas
# Top words in document  Pancreatic Cancer
# Top words in document  Pancreatitis
# Top words in document  Panic Attack
# Top words in document  Pap Test
# Top words in document  Paranoid Behavior
# Top words in document  Paraphimosis
# Top words in document  Parenting
# Top words in document  Parkinson's Disease
# Top words in document  Peanut
# Top words in document  Peanut Butter
# Top words in document  Pedialyte
# Top words in document  Pelvic Area
# Top words in document  Pelvis
# Top words in document  Penicillin
# Top words in document  Penile Cancer
# Top words in document  Penis
# Top words in document  Peptic Ulcer
# Top words in document  Perimenopause
# Top words in document  Period
# Top words in document  Periodontitis
# Top words in document  Peripheral Artery Disease
# Top words in document  Pets
# Top words in document  Physical Therapy
# Top words in document  Piercing
# Top words in document  Pilates
# Top words in document  Pilonidal Cyst
# Top words in document  Pinched Nerve
# Top words in document  Pink Eye
# Top words in document  Plant
# Top words in document  Plantar Fasciitis
# Top words in document  Plantar Wart
# Top words in document  Plastic Surgery
# Top words in document  Pleurisy
# Top words in document  Pneumonia
# Top words in document  Poison Ivy
# Top words in document  Poison Oak
# Top words in document  Poisoning
# Top words in document  Polycystic Ovarian Syndrome
# Top words in document  Polyp
# Top words in document  Pore
# Top words in document  Pork
# Top words in document  Post-Menopause
# Top words in document  Post-Traumatic Stress Disorder
# Top words in document  Postpartum Depression
# Top words in document  Potassium
# Top words in document  Potato
# Top words in document  Pregnancy
# Top words in document  Pregnancy Test
# Top words in document  Premature Ejaculation
# Top words in document  Premature Menopause
# Top words in document  Prenatal Vitamin
# Top words in document  Pressure
# Top words in document  Priapism
# Top words in document  Prostate
# Top words in document  Prostate Cancer
# Top words in document  Prostate-Specific Antigen Test
# Top words in document  Protein
# Top words in document  Protein S Deficiency
# Top words in document  Proton Pump Inhibitor
# Top words in document  Psoriasis
# Top words in document  Puffiness
# Top words in document  Pulmonary Embolism
# Top words in document  Pulse
# Top words in document  Pupil
# Top words in document  Quit Smoking
# Top words in document  Radial Keratotomy
# Top words in document  Radical Prostatectomy
# Top words in document  Radiculopathy
# Top words in document  Rash
# Top words in document  Raspberry
# Top words in document  Reaction
# Top words in document  Red Wine
# Top words in document  Rehabilitation
# Top words in document  Restless Leg Syndrome
# Top words in document  Restless Legs Syndrome
# Top words in document  Restlessness
# Top words in document  Retina
# Top words in document  Retrograde Ejaculation
# Top words in document  Rheumatoid Arthritis
# Top words in document  Rhinoplasty
# Top words in document  Rice
# Top words in document  Ringworm
# Top words in document  Rosacea
# Top words in document  Running
# Top words in document  Runny Nose
# Top words in document  SIDS
# Top words in document  Salad
# Top words in document  Salmon
# Top words in document  Salt
# Top words in document  Scabies
# Top words in document  Scalp
# Top words in document  Scar
# Top words in document  Schizophrenia
# Top words in document  Sciatica
# Top words in document  Scleroderma
# Top words in document  Scoliosis
# Top words in document  Scrape
# Top words in document  Screening
# Top words in document  Scrotum
# Top words in document  Sea Sickness
# Top words in document  Seborrhea
# Top words in document  Second Degree Burn
# Top words in document  Seizure
# Top words in document  Self-Exam
# Top words in document  Sepsis
# Top words in document  Serotonin
# Top words in document  Sexual Dysfunction
# Top words in document  Sexual Intercourse
# Top words in document  Sexual Problem
# Top words in document  Sexually Transmitted Disease
# Top words in document  Shaving
# Top words in document  Shellfish
# Top words in document  Shift Work Sleep Disorder
# Top words in document  Shingles
# Top words in document  Short Stature
# Top words in document  Shoulder
# Top words in document  Sinus
# Top words in document  Sinus Infection
# Top words in document  Skin
# Top words in document  Skin Cancer
# Top words in document  Skin Tag
# Top words in document  Sleep Apnea
# Top words in document  Sleep Disorder
# Top words in document  Sleepiness
# Top words in document  Sleepwalking
# Top words in document  Smell
# Top words in document  Smoking
# Top words in document  Snack
# Top words in document  Snorer
# Top words in document  Soda
# Top words in document  Sodium
# Top words in document  Sore
# Top words in document  Sore Throat
# Top words in document  Soup
# Top words in document  Soy
# Top words in document  Spasm
# Top words in document  Sperm
# Top words in document  Spider Bite
# Top words in document  Spider Vein
# Top words in document  Spina Bifida
# Top words in document  Spinach
# Top words in document  Spinal Stenosis
# Top words in document  Spit
# Top words in document  Spondylitis
# Top words in document  Spotting
# Top words in document  Sprain
# Top words in document  Squash
# Top words in document  St. John's Wort
# Top words in document  Staph Infection
# Top words in document  Stent
# Top words in document  Steroid
# Top words in document  Sting
# Top words in document  Stitches
# Top words in document  Stomach
# Top words in document  Stomach Cancer
# Top words in document  Stomachache
# Top words in document  Strep Throat
# Top words in document  Stress
# Top words in document  Stress Fracture
# Top words in document  Stress Incontinence
# Top words in document  Stretch Mark
# Top words in document  Stroke
# Top words in document  Stuffy Nose
# Top words in document  Sty
# Top words in document  Suicide
# Top words in document  Sulfur
# Top words in document  Sunburn
# Top words in document  Sunscreen
# Top words in document  Supplement
# Top words in document  Surgery
# Top words in document  Swallow
# Top words in document  Swallowing Problem
# Top words in document  Sweating
# Top words in document  Sweet Potato
# Top words in document  Swelling
# Top words in document  Swine Flu
# Top words in document  Syrup
# Top words in document  Systemic
# Top words in document  Tai Chi
# Top words in document  Taste
# Top words in document  Tattoo
# Top words in document  Tea
# Top words in document  Teething
# Top words in document  Temperature
# Top words in document  Tendon
# Top words in document  Tendonitis
# Top words in document  Tension Headache
# Top words in document  Testicle
# Top words in document  Testicular Cancer
# Top words in document  Testosterone
# Top words in document  Tetanus
# Top words in document  Thermometer
# Top words in document  Thigh
# Top words in document  Third Trimester
# Top words in document  Throat
# Top words in document  Thrush
# Top words in document  Thumb
# Top words in document  Thyroid
# Top words in document  Thyroiditis
# Top words in document  Tick
# Top words in document  Tightness
# Top words in document  Tinnitus
# Top words in document  Toddler
# Top words in document  Toe
# Top words in document  Tofu
# Top words in document  Tomato
# Top words in document  Tongue
# Top words in document  Tonsil
# Top words in document  Tooth
# Top words in document  Tooth Decay
# Top words in document  Toothache
# Top words in document  Torso
# Top words in document  Torticollis
# Top words in document  Transfusion
# Top words in document  Transient Ischemia Attack
# Top words in document  Trauma
# Top words in document  Travel
# Top words in document  Traveler's Diarrhea
# Top words in document  Tremor
# Top words in document  Tryptophan
# Top words in document  Tuberculosis
# Top words in document  Turkey
# Top words in document  Type 1 Diabetes
# Top words in document  Type 2 Diabetes
# Top words in document  Ulcer
# Top words in document  Ulcerative Colitis
# Top words in document  Ultrasound
# Top words in document  Urethra
# Top words in document  Uric Acid
# Top words in document  Urinary Incontinence
# Top words in document  Urinary Tract Infection
# Top words in document  Urination
# Top words in document  Uterus
# Top words in document  Vaccination
# Top words in document  Vaccines
# Top words in document  Vagina
# Top words in document  Vaginal Discharge
# Top words in document  Varicose Vein
# Top words in document  Vascular Dementia
# Top words in document  Vasectomy
# Top words in document  Vegetable
# Top words in document  Vein
# Top words in document  Vinegar
# Top words in document  Virus
# Top words in document  Vision
# Top words in document  Vitamin
# Top words in document  Vitamin A
# Top words in document  Vitamin C
# Top words in document  Vitamin D
# Top words in document  Vitamin K
# Top words in document  Vitiligo
# Top words in document  Vocal Cord
# Top words in document  Vomit
# Top words in document  Waist
# Top words in document  Walking
# Top words in document  Walnut
# Top words in document  Wart
# Top words in document  Weakness
# Top words in document  Weight
# Top words in document  Weight Gain
# Top words in document  Weight Loss
# Top words in document  Weight Loss Pill
# Top words in document  Wheat
# Top words in document  Whooping Cough
# Top words in document  Wine
# Top words in document  Wisdom Tooth
# Top words in document  Workout
# Top words in document  Worm
# Top words in document  Wound
# Top words in document  Wrinkle
# Top words in document  Wrist
# Top words in document  X-ray
# Top words in document  Yeast
# Top words in document  Yeast Infection
# Top words in document  Yoga
# Top words in document  Yogurt
# Top words in document  Zinc
# Top words in document  Zinc Oxide
# Top words in document  flaxseed oil

# %%
#Train Word2vec model
trainModel(modelName, modelMinCount, modelDimensions)
model = gensim.models.Word2Vec.load(modelName)

# %%
word2VecTopK(word2VecLimit)

# %%
generateMemberList()

# %%
generateTopicMemberList()

# %%
generateMemberLocation()

# %%
sortTop10TopicMemberList()

# %%
getStateForTopic()

# %%
getExpertAnswers()

# %%
getDatesHour()

# %%
getDatesYear()
